# %%
language = "German"
ueq_items = {
    "German": {
        "L6": "langweilig",
        "R6": "spannend",
        "L7": "uninteressant",
        "R7": "interessant",
        "L10": "originell",
        "R10": "konventionell",
        "L11": "behindernd",
        "R11": "unterstützend",
        "L13": "kompliziert",
        "R13": "einfach",
        "L15": "herkömmlich",
        "R15": "neuartig",
        "L20": "ineffizient",
        "R20": "effizient",
        "L21": "übersichtlich",
        "R21": "verwirrend",
        "Pragmatic Quality": "Pragmatische Qualität",
        "Hedonic Quality": "Hedonische Qualität"
    },
    "English": {
        "L6": "boring",
        "R6": "exciting",
        "L7": "not interesting",
        "R7": "interesting",
        "L10": "inventive",
        "R10": "conventional",
        "L11": "obstructive",
        "R11": "supportive",
        "L13": "complicated",
        "R13": "easy",
        "L15": "usual",
        "R15": "leading edge",
        "L20": "inefficient",
        "R20": "efficient",
        "L21": "clear",
        "R21": "confusing",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Spanish": {
        "L6": "aburrido",
        "R6": "emocionante",
        "L7": "no interesante",
        "R7": "interesante",
        "L10": "original",
        "R10": "convencional",
        "L11": "obstructivo",
        "R11": "impulsor de apoyo",
        "L13": "complicado",
        "R13": "facil",
        "L15": "convencional",
        "R15": "novedoso",
        "L20": "ineficiente",
        "R20": "eficiente",
        "L21": "claro",
        "R21": "confuso",
        "Pragmatic Quality": "Calidad Pragmática",
        "Hedonic Quality": "Calidad Hedónico"
    },
    "Portuguese": {
        "L6": "Aborrecido",
        "R6": "Excitante",
        "L7": "Desinteressante",
        "R7": "Interessante",
        "L10": "Original",
        "R10": "Convencional",
        "L11": "Obstrutivo",
        "R11": "Condutor",
        "L13": "Complicado",
        "R13": "Fácil",
        "L15": "Comum",
        "R15": "Vanguardista",
        "L20": "Ineficiente",
        "R20": "Eficiente",
        "L21": "Evidente",
        "R21": "Confuso",
        "Pragmatic Quality": "Qualidade Pragmática",
        "Hedonic Quality": "Qualidade Hedônica"
    },
    "Turkish": {
        "L6": "sıkıcı",
        "R6": "heyecan verici",
        "L7": "ilginç olmayan",
        "R7": "ilginç",
        "L10": "özgün",
        "R10": "geleneksel",
        "L11": "engelleyici",
        "R11": "destekleyici",
        "L13": "karmaşık",
        "R13": "sade",
        "L15": "alışıldık",
        "R15": "eşi görülmedik",
        "L20": "verimsiz",
        "R20": "verimli",
        "L21": "açık",
        "R21": "kafa karıştırıcı",
        "Pragmatic Quality": "Pragmatik Kalite",
        "Hedonic Quality": "Hedonik Kalite"
    },
    "French": {
        "L6": "Ennuyeux",
        "R6": "Captivant",
        "L7": "Inintéressant",
        "R7": "Intéressant",
        "L10": "Original",
        "R10": "Conventionnel",
        "L11": "Rigide",
        "R11": "Facilitant",
        "L13": "Compliqué",
        "R13": "Simple",
        "L15": "Habituel",
        "R15": "Avant-gardiste",
        "L20": "Inefficace",
        "R20": "Efficace",
        "L21": "Clair",
        "R21": "Déroutant",
        "Pragmatic Quality": "Qualité Pragmatique",
        "Hedonic Quality": "Qualité Hédonique"
    },
    "Italian": {
        "L6": "noioso",
        "R6": "appassionante",
        "L7": "non interessante",
        "R7": "interessante",
        "L10": "originale",
        "R10": "convenzionale",
        "L11": "ostruttiva",
        "R11": "di supporto",
        "L13": "complicato",
        "R13": "facile",
        "L15": "usuale",
        "R15": "moderno",
        "L20": "inefficiente",
        "R20": "efficiente",
        "L21": "chiaro",
        "R21": "confuso",
        "Pragmatic Quality": "Qualità Pragmatico",
        "Hedonic Quality": "Qualità eEonica"
    },
    "Russian": {
        "L6": "скучный",
        "R6": "захватывающий",
        "L7": "неинтересный",
        "R7": "интересный",
        "L10": "изобретательный",
        "R10": "консервативный",
        "L11": "мешающий",
        "R11": "помогающий",
        "L13": "сложный",
        "R13": "простой",
        "L15": "обыденный",
        "R15": "передовой",
        "L20": "неэффективный",
        "R20": "эффективный",
        "L21": "наглядный",
        "R21": "запутанный",
        "Pragmatic Quality": "Прагматические качество",
        "Hedonic Quality": "гедонистическоe качествo"
    },
    "Chinese": {
        "L6": "乏味的 ",
        "R6": "带劲的",
        "L7": "无趣的",
        "R7": "有趣的",
        "L10": "独创的",
        "R10": "常规的",
        "L11": "碍手碍脚的",
        "R11": "能提供辅助的",
        "L13": "复杂的",
        "R13": "简单的",
        "L15": "传统的",
        "R15": "新颖的",
        "L20": "低效的",
        "R20": "高效的",
        "L21": "一目了然的",
        "R21": "令人眼花缭乱的",
        "Pragmatic Quality": "务实的品质",
        "Hedonic Quality": "享乐质量"
    },
    "Japanese": {
        "L6": "退屈だ",
        "R6": "エキサイティングだ",
        "L7": "おもしろくない",
        "R7": "おもしろい",
        "L10": "独特だ",
        "R10": "従来どおり",
        "L11": "妨げになる",
        "R11": "助けられる",
        "L13": "複雑",
        "R13": "簡単",
        "L15": "普通",
        "R15": "斬新的",
        "L20": "効率が悪い",
        "R20": "効率が良い",
        "L21": "すっきりしている",
        "R21": "ごちゃごちゃしている",
        "Pragmatic Quality": "実用的な品質",
        "Hedonic Quality": "ヘドニック品質"
    },
    "Indonesian": {
        "L6": "membosankan",
        "R6": "mengasyikkan",
        "L7": "tidak menarik",
        "R7": "menarik",
        "L10": "berdaya cipta",
        "R10": "konvensional",
        "L11": "menghalangi",
        "R11": "mendukung",
        "L13": "rumit",
        "R13": "sederhana",
        "L15": "lazim",
        "R15": "terdepan",
        "L20": "tidak efisien",
        "R20": "efisien",
        "L21": "jelas",
        "R21": "membingungkan",
        "Pragmatic Quality": "Kualitas Pragmatis",
        "Hedonic Quality": "Kualitas Hedonis"
    },
    "Dutch": {
        "L6": "vervelend",
        "R6": "spannend",
        "L7": "oninteressant",
        "R7": "interessant",
        "L10": "origineel",
        "R10": "conventioneel",
        "L11": "belemmerend",
        "R11": "ondersteunend",
        "L13": "complex",
        "R13": "eenvoudig",
        "L15": "gebruikelijk",
        "R15": "nieuw",
        "L20": "inefficiënt",
        "R20": "efficiënt",
        "L21": "overzichtelijk",
        "R21": "verwarrend",
        "Pragmatic Quality": "Pragmatische Kwaliteit",
        "Hedonic Quality": "Hedonistische Kwaliteit"
    },
    "Estonian": {
        "L6": "igav",
        "R6": "põnev",
        "L7": "ebahuvitav",
        "R7": "huvitav",
        "L10": "leidlik",
        "R10": "konservatiivne",
        "L11": "takistav",
        "R11": "abistav",
        "L13": "keeruline",
        "R13": "lihtne",
        "L15": "tavaline",
        "R15": "uuenduslik",
        "L20": "ebaefektiivne",
        "R20": "efektiivne",
        "L21": "selge ",
        "R21": "ebamäärane",
        "Pragmatic Quality": "Pragmaatiline kvaliteet (tarbekvaliteet)",
        "Hedonic Quality": "Hedooniline kvaliteet (hinnang meeldivuse järgi)"
    },
    "Slovene": {
        "L6": "dolgočasen",
        "R6": "napet",
        "L7": "nezanimiv",
        "R7": "zanimiv",
        "L10": "nov",
        "R10": "star",
        "L11": "se ne da upravljati",
        "R11": "se z lahkoto upravlja",
        "L13": "kompliciran",
        "R13": "enostaven",
        "L15": "zastarel",
        "R15": "modern",
        "L20": "ni učinkovit",
        "R20": "učinkovit",
        "L21": "pregleden",
        "R21": "ustvarja zmedo",
        "Pragmatic Quality": "pragmatično kakovosti",
        "Hedonic Quality": "hedonsko kakovosti"
    },
    "Swedish": {
        "L6": "Tråkig",
        "R6": "Spännande",
        "L7": "Ointressant",
        "R7": "Intressant",
        "L10": "Uppfinningsrik",
        "R10": "Fantasilös",
        "L11": "Hindrande",
        "R11": "Stödjande",
        "L13": "Komplicerad",
        "R13": "Enkel",
        "L15": "Bakåtsträvande",
        "R15": "I framkant",
        "L20": "Ineffektiv",
        "R20": "Effektiv",
        "L21": "Tydlig",
        "R21": "Förvirrande",
        "Pragmatic Quality": "Pragmatiska kvaliteter",
        "Hedonic Quality": "Hedoniska kvaliteter"
    },
    "Greek": {
        "L6": "βαρετό",
        "R6": "συναρπαστικό",
        "L7": "αδιάφορο",
        "R7": "ενδιαφέρον",
        "L10": "εφευρετικό",
        "R10": "συμβατικό",
        "L11": "παρελκυστικό",
        "R11": "υποστηρικτικό",
        "L13": "περίπλοκο",
        "R13": "εύκολο",
        "L15": "συνηθισμένο",
        "R15": "πρωτοπόρο",
        "L20": "ανεπαρκές",
        "R20": "επαρκές",
        "L21": "σαφές",
        "R21": "μπερδεμένο",
        "Pragmatic Quality": "ρεαλιστική ποιότητα",
        "Hedonic Quality": "ηδονική ποιότητας"
    },
    "Polish": {
        "L6": "nudny",
        "R6": "ekscytujący",
        "L7": "nieinteresujący",
        "R7": "interesujący",
        "L10": "pomysłowy",
        "R10": "konwencjonalny",
        "L11": "przeszkadzający",
        "R11": "wspierający",
        "L13": "skomplikowany",
        "R13": "łatwy",
        "L15": "zwykły",
        "R15": "skrajny",
        "L20": "nieefektywny",
        "R20": "efektywny",
        "L21": "przejrzysty",
        "R21": "zagmatwany",
        "Pragmatic Quality": "Pragmatyczne jakości",
        "Hedonic Quality": "Hedoniczna jakości"
    },
    "Hindi": {
        "L6": "उबाऊ ",
        "R6": "दिलचस्प",
        "L7": "दिलचस्प नहीं",
        "R7": "दिलचस्प",
        "L10": "आविष्कारशील ",
        "R10": "परम्परागत",
        "L11": "प्रतिरोधी ",
        "R11": " सहायक",
        "L13": "जटिल ",
        "R13": "आसान",
        "L15": "हमेशा की तरह ",
        "R15": "अग्रणी धार",
        "L20": "अक्षम ",
        "R20": "कुशल",
        "L21": "स्पष्ट ",
        "R21": "भ्रमित",
        "Pragmatic Quality": "व्यावहारिक गुणवत्ता",
        "Hedonic Quality": "सुखात्मक  गुणवत्ता"
    },
    "Bulgarian": {
        "L6": "скучен",
        "R6": "вълнуващ",
        "L7": "безинтересен",
        "R7": "интересен",
        "L10": "идеен",
        "R10": "конвенционален",
        "L11": "възпрепятстващ",
        "R11": "помагащ",
        "L13": "сложен",
        "R13": "лесен",
        "L15": "обикновен",
        "R15": "иновативен",
        "L20": "Мотлив",
        "R20": "Експедитивен",
        "L21": "ясен",
        "R21": "объркващ",
        "Pragmatic Quality": "Прагматично качество",
        "Hedonic Quality": "Хедонично качество"
    },
    "Czech": {
        "L6": "nudný",
        "R6": "vzrušující",
        "L7": "nezajímavý",
        "R7": "zajímavý",
        "L10": "vynalézavý",
        "R10": "obvyklý",
        "L11": "bránící",
        "R11": "podporující",
        "L13": "složitý",
        "R13": "jednoduchý",
        "L15": "tradiční",
        "R15": "moderní",
        "L20": "neefektivní",
        "R20": "efektivní",
        "L21": "jasný",
        "R21": "matoucí",
        "Pragmatic Quality": "Pragmatická kvalita",
        "Hedonic Quality": "Hédonická kvalita"
    },
    "Malay": {
        "L6": "membosankan",
        "R6": "menyeronokkan",
        "L7": "tidak menarik minat",
        "R7": "menarik minat",
        "L10": "terdapat rekaan baharu",
        "R10": "berdasarkan kebiasaan",
        "L11": "menghalang",
        "R11": "menyokong",
        "L13": "menyulitkan",
        "R13": "mudah",
        "L15": "biasa",
        "R15": "mempunyai kelebihan",
        "L20": "tidak berkesan",
        "R20": "berkesan",
        "L21": "jelas",
        "R21": "mengelirukan",
        "Pragmatic Quality": "Kualiti yang berguna",
        "Hedonic Quality": "Kualiti Kesenangan"
    },
    "Persian": {
        "L6": "خسته کننده",
        "R6": "جذاب",
        "L7": "عدم جذابیت",
        "R7": "جذاب",
        "L10": "نوآوری/مبتکر",
        "R10": "مرسوم/سنتی",
        "L11": "مختل کننده",
        "R11": "پشتیبان",
        "L13": "پیچیده",
        "R13": "آسان",
        "L15": "معمولی",
        "R15": "پیشرو در فناوری",
        "L20": "عدم کفایت",
        "R20": "کافی",
        "L21": "واضح",
        "R21": "گیج کننده/مبهم",
        "Pragmatic Quality": "کیفیت استفاده",
        "Hedonic Quality": "کیفیت طراحی"
    },
    "Thai": {
        "L6": "น่าเบื่อ",
        "R6": "น่าตื่นเต้น",
        "L7": "ไม่น่าสนใจ",
        "R7": "น่าสนใจ",
        "L10": "ช่างประดิษฐ์",
        "R10": "ตามแบบแผน",
        "L11": "ขัดขวาง",
        "R11": "สนับสนุน",
        "L13": "ซับซ้อน",
        "R13": "เรียบง่าย",
        "L15": "ดูทั่วไป",
        "R15": "ดูชั้นนา",
        "L20": "ไร้ประสิทธิภาพ",
        "R20": "มีประสิทธิภาพ",
        "L21": "ชัดเจน",
        "R21": "สับสน",
        "Pragmatic Quality": "คุณภาพในทางปฏิบัติ",
        "Hedonic Quality": "คุณภาพความเพลิดเพลิน"
    },
    "Danish": {
        "L6": "kedelige",
        "R6": "spændende",
        "L7": "uinteressante",
        "R7": "interessante",
        "L10": "opfindsom",
        "R10": "traditionsbunden",
        "L11": "hindrende",
        "R11": "understøttende",
        "L13": "indviklede",
        "R13": "nemme",
        "L15": "sædvanlig",
        "R15": "avanceret",
        "L20": "ineffektivt",
        "R20": "ydedygtigt",
        "L21": "tydelige",
        "R21": "forvirrende",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Norwegian": {
        "L6": "kjedelig",
        "R6": "spennende",
        "L7": "uinteressant",
        "R7": "interessant",
        "L10": "oppfinnsom",
        "R10": "tradisjonell",
        "L11": "hindrende",
        "R11": "støttende",
        "L13": "komplisert",
        "R13": "lett",
        "L15": "vanlig",
        "R15": "ledende",
        "L20": "ineffektivt",
        "R20": "effektivt",
        "L21": "tydelig",
        "R21": "forvirrende",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Finnish": {
        "L6": "pitkäveteistä",
        "R6": "jännittävää",
        "L7": "yksitoikkoista",
        "R7": "kiinnostavaa",
        "L10": "kekseliäs",
        "R10": "perinteinen",
        "L11": "vaikeuttavaa",
        "R11": "tukevaa",
        "L13": "monimutkaista",
        "R13": "helppoa",
        "L15": "tavanomainen",
        "R15": "huippulaatuinen",
        "L20": "tehoton",
        "R20": "tehokas",
        "L21": "selkeätä",
        "R21": "sekavaa",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Hungarian": {
        "L6": "unalmas",
        "R6": "izgalmas",
        "L7": "nem érdekes",
        "R7": "érdekes",
        "L10": "ötletes",
        "R10": "szokványos",
        "L11": "hátráltatók",
        "R11": "támogatók",
        "L13": "bonyolult",
        "R13": "könnyű",
        "L15": "átlagos",
        "R15": "élvonalban lévő",
        "L20": "nem hatékony",
        "R20": "hatékony",
        "L21": "világos",
        "R21": "nehezen értelmezhető",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Croatian": {
        "L6": "dosadan",
        "R6": "uzbudljiv",
        "L7": "nezanimljiv",
        "R7": "zanimljiv",
        "L10": "originalan",
        "R10": "neoriginalan",
        "L11": "ometajući",
        "R11": "podupirući",
        "L13": "kompliciran",
        "R13": "jednostavan",
        "L15": "uobičajen",
        "R15": "nov",
        "L20": "neučinkovit",
        "R20": "učinkovit",
        "L21": "jasan",
        "R21": "zbunjujuć",
        "Pragmatic Quality": "Pragmatična kvaliteta",
        "Hedonic Quality": "Hedonička kvaliteta"
    },
    "Bosnian": {
        "L6": "dosadni",
        "R6": "uzbudljivi",
        "L7": "nezanimljivi",
        "R7": "zanimljivi",
        "L10": "domišljati",
        "R10": "uobičajeni",
        "L11": "ometajući",
        "R11": "od pomoći",
        "L13": "složeni",
        "R13": "jednostavni",
        "L15": "svakodnevni",
        "R15": "vrhunski",
        "L20": "neefikasan",
        "R20": "efikasan",
        "L21": "jasni",
        "R21": "zbunjujući",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Hebrew": {
        "L6": "משעממים",
        "R6": "מלהיבים",
        "L7": "לא מעניינים",
        "R7": "מעניינים",
        "L10": "פורצי דרך",
        "R10": "שגרתיים",
        "L11": "מכשילות",
        "R11": "תומכות",
        "L13": "מסובכים",
        "R13": "קלים",
        "L15": "רגילים",
        "R15": "בחזית החדשנות",
        "L20": "לא יעיל",
        "R20": "יעיל",
        "L21": "ברורים",
        "R21": "מבלבלים",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Arabic": {
        "L6": "ممل",
        "R6": "مثير",
        "L7": "غير مثير للاهتمام",
        "R7": "مثير للاهتمام",
        "L10": "مستحدَث",
        "R10": "تقليدي",
        "L11": "عائق",
        "R11": "داعم",
        "L13": "معقَّد",
        "R13": "بسيط",
        "L15": "اعتيادي",
        "R15": "جديد من نوعه",
        "L20": "غير فعَّال",
        "R20": "فعَّال",
        "L21": "واضح",
        "R21": "مُربك",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Bengali": {
        "L6": "একঘেয়ে",
        "R6": "উত্তেজনাপূর্ণ",
        "L7": "আকর্ষণীয়নয়",
        "R7": "মজাদার",
        "L10": "উদ্ভাবক",
        "R10": "গতানুগতিক",
        "L11": "প্রতিবন্ধক",
        "R11": "সহায়ক",
        "L13": "জটিল",
        "R13": "সহজ",
        "L15": "সাধারণ",
        "R15": "নেতৃস্থানীয়",
        "L20": "অকার্যকর",
        "R20": "কার্যকর",
        "L21": "স্পষ্ট",
        "R21": "বিভ্রান্তিকর",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Kannada": {
        "L6": "ನೀರಸವಾದ",
        "R6": "ನೀರಸವಾದ",
        "L7": "ಕುತೂಹಲವಲ್ಲದ",
        "R7": "ಕುತೂಹಲವಲ್ಲದ",
        "L10": "ಹೊಸದಾಗಿ ಕಂಡುಹಿಡಿದಂತಹ",
        "R10": "ಹೊಸದಾಗಿ ಕಂಡುಹಿಡಿದಂತಹ",
        "L11": "ಪ್ರತಿರೋಧಿಸುವ",
        "R11": "ಪ್ರತಿರೋಧಿಸುವ",
        "L13": "ಕ್ಲಿಷ್ಟಕರ",
        "R13": "ಕ್ಲಿಷ್ಟಕರ",
        "L15": "ಸಾಮಾನ್ಯ",
        "R15": "ಸಾಮಾನ್ಯ",
        "L20": "ದಕ್ಷವಲ್ಲದ",
        "R20": "ದಕ್ಷವಲ್ಲದ",
        "L21": "ಸ್ಪಷ್ಟತೆ",
        "R21": "ಸ್ಪಷ್ಟತೆ",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Marathi": {
        "L6": "कंटाळवाणा",
        "R6": "बाहेर पडत आहे",
        "L7": "मनोरंजक नाही",
        "R7": "मनोरंजक",
        "L10": "शोधक",
        "R10": "पारंपारिक",
        "L11": "अडवणूक करणारा",
        "R11": "आधार देणारा",
        "L13": "बिकट",
        "R13": "सोपे",
        "L15": "नेहमीच्या",
        "R15": "पुढचे टोक",
        "L20": "अकार्यक्षम",
        "R20": "कार्यक्षम",
        "L21": "स्पष्ट",
        "R21": "गोंधळात टाकणारे",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Tamil": {
        "L6": "சலிப்பான",
        "R6": "ஆர்வமான ",
        "L7": "சுவாரஸ்யம் இல்லை",
        "R7": "சுவாரஸ்யம் ",
        "L10": "கண்டுபிடிப்பு ",
        "R10": "வழக்கமான ",
        "L11": "தடை செய்யும் ",
        "R11": "ஆதரவு ",
        "L13": "சிக்கலான ",
        "R13": "சுலபம் ",
        "L15": "சாதாரணமான",
        "R15": "முன்னணி விளிம்பு ",
        "L20": "திறனற்ற",
        "R20": "திறன் ",
        "L21": "தெளிவு  ",
        "R21": "குழப்பமான ",
        "Pragmatic Quality": "Pragmatic Quality",
        "Hedonic Quality": "Hedonic Quality"
    },
    "Slovak": {
        "L6": "nudný",
        "R6": "vzrušujúci",
        "L7": "nezaujímavý",
        "R7": "zaujímavý",
        "L10": "moderný",
        "R10": "tradičný",
        "L11": "obmedzujúci",
        "R11": "podporujúci",
        "L13": "zložitý",
        "R13": "jednoduchý",
        "L15": "bežný",
        "R15": "špičkový",
        "L20": "neefektívny",
        "R20": "efektívny",
        "L21": "jasný",
        "R21": "mätúci",
        "Pragmatic Quality": "Pragmatická kvalita",
        "Hedonic Quality": "Hedonická kvalita"
    }
};

# %%
import pandas as pd
import numpy as np

# Read the Excel file
df = pd.read_csv('ueqtest.csv')

# Apply the first formula
df = df.applymap(lambda x: x-4 if x > 0 else "")

# Define a function for calculating the mean if count of numbers > 0
def mean_if_count_greater_than_zero(columns):
    values = columns.dropna().astype(float)
    return values.mean() if len(values) > 0 else ""

# Create the new columns
df[ueq_items[language]['Pragmatic Quality']] = df.iloc[:, 0:4].apply(mean_if_count_greater_than_zero, axis=1)
df[ueq_items[language]['Hedonic Quality']] = df.iloc[:, 4:8].apply(mean_if_count_greater_than_zero, axis=1)
df['Overall'] = df.iloc[:, 0:8].apply(mean_if_count_greater_than_zero, axis=1)

df
# Out:
#     1  2  3  4  5  6  7  8  Pragmatische Qualität  Hedonische Qualität  \
# 0  -3  2  0  1 -1  0 -1  1                   0.00                -0.25
# 1   1  1  0  1 -2 -1  0  1                   0.75                -0.50
# 2   2  3 -2  1  1  2  1  0                   1.00                 1.00
# 3   1  2  2  0  0  2  2  0                   1.25                 1.00
# 4   0  0  0  1  1  1  0  1                   0.25                 0.75
# 5   2  0  0  1  2  2  1  1                   0.75                 1.50
# 6   1  2  2  2 -1  0  0 -1                   1.75                -0.50
# 7   3  2  0  1  1 -1  1  0                   1.50                 0.25
# 8   3  3  2  1  0  2  1  1                   2.25                 1.00
# 9   2  2  1  1  2  1  2  2                   1.50                 1.75
# 10  0  0  0  0  0  0  0  0                   0.00                 0.00
# 11  1  1  1  1  1  1  1  1                   1.00                 1.00
# ...

# %%
# Calculate the new values
pragmatische_qualität = df[ueq_items[language]['Pragmatic Quality']].mean()
hedonische_qualität = df[ueq_items[language]['Hedonic Quality']].mean()
overall = df['Overall'].mean()
results_df = pd.DataFrame({
    ueq_items[language]['Pragmatic Quality']: [pragmatische_qualität],
    ueq_items[language]['Hedonic Quality']: [hedonische_qualität],
    'Overall': [overall]
})
results_df
# Out:
#    Pragmatische Qualität  Hedonische Qualität   Overall
# 0               0.903846             0.519231  0.711538

# %%
columns_to_exclude = [ueq_items[language]['Pragmatic Quality'], ueq_items[language]['Hedonic Quality'], 'Overall']
filtered_columns = [col for col in df.columns if col not in columns_to_exclude]
filtered_df = df[filtered_columns]
result_df = pd.DataFrame({
    'Item': filtered_df.columns,
    'Mean': filtered_df.mean(),
    'Variance': filtered_df.var(),
    'Std. Dev.': filtered_df.std(),
    'No.': filtered_df.count(),
    "Negative": [ueq_items[language][["L11","L13","L20","R21","L6","L7","R10","L15"][int(col)-1]] for col in filtered_df.columns],
    "Positive": [ueq_items[language][["R11","R13","R20","L21","R6","R7","L10","R15"][int(col)-1]] for col in filtered_df.columns],
}).reset_index(drop=True)
result_df
# Out:
#   Item      Mean  Variance  Std. Dev.  No.       Negative       Positive
# 0    1  0.769231  3.692308   1.921538   13     behindernd  unterstützend
# 1    2  1.538462  1.102564   1.050031   13    kompliziert        einfach
# 2    3  0.230769  2.192308   1.480644   13    ineffizient      effizient
# 3    4  1.076923  0.576923   0.759555   13     verwirrend  übersichtlich
# 4    5  0.076923  2.243590   1.497862   13     langweilig       spannend
# 5    6  0.692308  1.230769   1.109400   13  uninteressant    interessant
# 6    7  0.846154  1.141026   1.068188   13  konventionell      originell
# 7    8  0.461538  0.769231   0.877058   13    herkömmlich       neuartig

# %%
final_data_df = pd.read_csv('./final_data.csv')

# Get the UEQ columns grouped by the condition column
ueq_columns = [col for col in final_data_df.columns if col.startswith(
    'UEQ')] + ['Condition']


# Filter the DataFrame to only include the relevant columns
filtered_df = final_data_df[ueq_columns]

# Print all rows with condition equals control
filtered_df[filtered_df['Condition'] == 'Control'].drop(columns=['Condition']).to_csv('ueq_control.csv', index=False)
filtered_df[filtered_df['Condition'] == 'Visual'].drop(columns=['Condition']).to_csv('ueq_visual.csv', index=False)
filtered_df[filtered_df['Condition'] == 'EMS'].drop(columns=['Condition']).to_csv('ueq_ems.csv', index=False)
filtered_df[filtered_df['Condition'] == 'EMSVisual'].drop(columns=['Condition']).to_csv('ueq_emsvisual.csv', index=False)
